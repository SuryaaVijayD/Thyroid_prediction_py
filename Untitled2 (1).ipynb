# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Thyroid_Diff.csv")
df.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# 1  T1a  N0  M0     I      Excellent       No
# 2  T1a  N0  M0     I      Excellent       No
# 3  T1a  N0  M0     I      Excellent       No
# 4  T1a  N0  M0     I      Excellent       No

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred'],
#       dtype='object')

# %%
arr=[ 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
       'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
       'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred']
for i in arr:
  print(f'{i}: ',df[i].unique())
# Out:
# Gender:  ['F' 'M']
# Smoking:  ['No' 'Yes']
# Hx Smoking:  ['No' 'Yes']
# Hx Radiothreapy:  ['No' 'Yes']
# Thyroid Function:  ['Euthyroid' 'Clinical Hyperthyroidism' 'Clinical Hypothyroidism'
#  'Subclinical Hyperthyroidism' 'Subclinical Hypothyroidism']
# Physical Examination:  ['Single nodular goiter-left' 'Multinodular goiter'
#  'Single nodular goiter-right' 'Normal' 'Diffuse goiter']
# Adenopathy:  ['No' 'Right' 'Extensive' 'Left' 'Bilateral' 'Posterior']
# Pathology:  ['Micropapillary' 'Papillary' 'Follicular' 'Hurthel cell']
# Focality:  ['Uni-Focal' 'Multi-Focal']
# Risk:  ['Low' 'Intermediate' 'High']
# T:  ['T1a' 'T1b' 'T2' 'T3a' 'T3b' 'T4a' 'T4b']
# N:  ['N0' 'N1b' 'N1a']
# M:  ['M0' 'M1']
# Stage:  ['I' 'II' 'IVB' 'III' 'IVA']
# Response:  ['Indeterminate' 'Excellent' 'Structural Incomplete'
#  'Biochemical Incomplete']
# Recurred:  ['No' 'Yes']

# %% [markdown]
# #UNIVARIATE STATS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
#  15  Response              383 non-null    object
#  16  Recurred              383 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 51.0+ KB

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
df.nunique()
# Out:
# Age                     65
# Gender                   2
# Smoking                  2
# Hx Smoking               2
# Hx Radiothreapy          2
# Thyroid Function         5
# Physical Examination     5
# Adenopathy               6
# Pathology                4
# Focality                 2
# Risk                     3
# T                        7
# N                        3
# M                        2
# Stage                    5
# Response                 4
# Recurred                 2
# dtype: int64

# %% [markdown]
# #BIVARIATE STATS

# %%
from sklearn.preprocessing import LabelEncoder

df[['Gender', 'Smoking','Hx Smoking','Hx Radiothreapy','Thyroid Function','Physical Examination','Adenopathy','Pathology','Focality','Risk','T','N','M','Stage','Response','Recurred']] = df[['Gender', 'Smoking','Hx Smoking','Hx Radiothreapy','Thyroid Function','Physical Examination','Adenopathy','Pathology','Focality','Risk','T','N','M','Stage','Response','Recurred']].apply(LabelEncoder().fit_transform)

print(df)
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 2
# 1     34       0        0           1                0                 2
# 2     30       0        0           0                0                 2
# 3     62       0        0           0                0                 2
# 4     62       0        0           0                0                 2
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 2
# 379   81       1        1           0                1                 2
# 380   72       1        1           1                0                 2
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 2
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk  T  N  M  \
# 0                       3           3          2         1     2  0  0  0
# 1                       1           3          2         1     2  0  0  0
# 2                       4           3          2         1     2  0  0  0
# 3                       4           3          2         1     2  0  0  0
# 4                       1           3          2         0     2  0  0  0
# ..                    ...         ...        ...       ...   ... .. .. ..
# 378                     4           5          3         1     0  6  2  1
# 379                     1           1          3         0     0  6  2  1
# 380                     1           0          3         0     0  6  2  1
# 381                     1           1          1         0     0  6  2  0
# 382                     1           0          3         0     0  6  2  0
#
#      Stage  Response  Recurred
# 0        0         2         0
# 1        0         1         0
# 2        0         1         0
# 3        0         1         0
# 4        0         1         0
# ..     ...       ...       ...
# 378      4         0         1
# 379      4         3         1
# 380      4         3         1
# 381      3         3         1
# 382      3         3         1
#
# [383 rows x 17 columns]

# %%
df.corr()
# Out:
#                            Age    Gender   Smoking  Hx Smoking  \
# Age                   1.000000  0.186457  0.309536    0.134531
# Gender                0.186457  1.000000  0.621886    0.175755
# Smoking               0.309536  0.621886  1.000000    0.252773
# Hx Smoking            0.134531  0.175755  0.252773    1.000000
# Hx Radiothreapy       0.176588  0.235865  0.297874    0.261198
# Thyroid Function      0.036043  0.037558  0.017750    0.022111
# Physical Examination -0.092546 -0.079013 -0.066707   -0.027658
# Adenopathy           -0.101509 -0.215953 -0.155523   -0.050382
# Pathology            -0.159689 -0.023539 -0.202167   -0.095052
# Focality             -0.223847 -0.207634 -0.238494   -0.001204
# Risk                 -0.295556 -0.295229 -0.374324   -0.138403
# T                     0.242670  0.271949  0.377728    0.151056
# N                     0.061243  0.238766  0.204305    0.044421
# M                     0.235401  0.211540  0.321233    0.127209
# Stage                 0.526862  0.250215  0.426152    0.262371
# Response              0.180643  0.272868  0.263184    0.042867
# Recurred              0.258897  0.328189  0.333243    0.136073
#
#                       Hx Radiothreapy  Thyroid Function  Physical Examination  \
# Age                          0.176588          0.036043             -0.092546
# Gender                       0.235865          0.037558             -0.079013
# Smoking                      0.297874          0.017750             -0.066707
# Hx Smoking                   0.261198          0.022111             -0.027658
# Hx Radiothreapy              1.000000         -0.112998             -0.013437
# Thyroid Function            -0.112998          1.000000              0.097316
# Physical Examination        -0.013437          0.097316              1.000000
# Adenopathy                  -0.057781         -0.044032              0.248599
# Pathology                   -0.106469          0.095392              0.001206
# Focality                    -0.102415         -0.067081              0.304883
# Risk                        -0.272056         -0.072472              0.187451
# T                            0.225794          0.067635             -0.140371
# N                            0.095535          0.093452             -0.141878
# M                            0.430214          0.017484             -0.010105
# Stage                        0.461901          0.046218             -0.105831
# Response                     0.105908          0.044829             -0.129953
# Recurred                     0.174407          0.067758             -0.131801
#
#                       Adenopathy  Pathology  Focality      Risk         T  \
# Age                    -0.101509  -0.159689 -0.223847 -0.295556  0.242670
# Gender                 -0.215953  -0.023539 -0.207634 -0.295229  0.271949
# Smoking                -0.155523  -0.202167 -0.238494 -0.374324  0.377728
# Hx Smoking             -0.050382  -0.095052 -0.001204 -0.138403  0.151056
# Hx Radiothreapy        -0.057781  -0.106469 -0.102415 -0.272056  0.225794
# Thyroid Function       -0.044032   0.095392 -0.067081 -0.072472  0.067635
# Physical Examination    0.248599   0.001206  0.304883  0.187451 -0.140371
# Adenopathy              1.000000  -0.015111  0.175732  0.182049 -0.207648
# Pathology              -0.015111   1.000000  0.030219  0.020351  0.007605
# Focality                0.175732   0.030219  1.000000  0.450615 -0.454832
# Risk                    0.182049   0.020351  0.450615  1.000000 -0.680255
# T                      -0.207648   0.007605 -0.454832 -0.680255  1.000000
# N                      -0.154281   0.241381 -0.376692 -0.696764  0.458701
# M                      -0.080491  -0.095974 -0.221931 -0.503143  0.388490
# Stage                  -0.150069  -0.111171 -0.331892 -0.619415  0.538309
# Response               -0.190686  -0.019872 -0.356521 -0.606071  0.459597
# Recurred               -0.182530   0.003272 -0.383776 -0.733376  0.556201
#
#                              N         M     Stage  Response  Recurred
# Age                   0.061243  0.235401  0.526862  0.180643  0.258897
# Gender                0.238766  0.211540  0.250215  0.272868  0.328189
# Smoking               0.204305  0.321233  0.426152  0.263184  0.333243
# Hx Smoking            0.044421  0.127209  0.262371  0.042867  0.136073
# Hx Radiothreapy       0.095535  0.430214  0.461901  0.105908  0.174407
# Thyroid Function      0.093452  0.017484  0.046218  0.044829  0.067758
# Physical Examination -0.141878 -0.010105 -0.105831 -0.129953 -0.131801
# Adenopathy           -0.154281 -0.080491 -0.150069 -0.190686 -0.182530
# Pathology             0.241381 -0.095974 -0.111171 -0.019872  0.003272
# Focality             -0.376692 -0.221931 -0.331892 -0.356521 -0.383776
# Risk                 -0.696764 -0.503143 -0.619415 -0.606071 -0.733376
# T                     0.458701  0.388490  0.538309  0.459597  0.556201
# N                     1.000000  0.219269  0.274281  0.583809  0.632323
# M                     0.219269  1.000000  0.681019  0.305077  0.354360
# Stage                 0.274281  0.681019  1.000000  0.337875  0.449137
# Response              0.583809  0.305077  0.337875  1.000000  0.708957
# Recurred              0.632323  0.354360  0.449137  0.708957  1.000000

# %%
df.corr().Recurred
# Out:
# Age                     0.258897
# Gender                  0.328189
# Smoking                 0.333243
# Hx Smoking              0.136073
# Hx Radiothreapy         0.174407
# Thyroid Function        0.067758
# Physical Examination   -0.131801
# Adenopathy             -0.182530
# Pathology               0.003272
# Focality               -0.383776
# Risk                   -0.733376
# T                       0.556201
# N                       0.632323
# M                       0.354360
# Stage                   0.449137
# Response                0.708957
# Recurred                1.000000
# Name: Recurred, dtype: float64

# %%
# pearson corr
from scipy import stats
r,p=stats.pearsonr(df.Recurred,df.Age)
r,p
# Out:
# (0.25889701090156697, 2.7765407961642556e-07)

# %%
df.Age.describe()
# Out:
# count    383.000000
# mean      40.866841
# std       15.134494
# min       15.000000
# 25%       29.000000
# 50%       37.000000
# 75%       51.000000
# max       82.000000
# Name: Age, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['Recurred'],axis=1)
y=df['Recurred']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    int64
#  2   Smoking               383 non-null    int64
#  3   Hx Smoking            383 non-null    int64
#  4   Hx Radiothreapy       383 non-null    int64
#  5   Thyroid Function      383 non-null    int64
#  6   Physical Examination  383 non-null    int64
#  7   Adenopathy            383 non-null    int64
#  8   Pathology             383 non-null    int64
#  9   Focality              383 non-null    int64
#  10  Risk                  383 non-null    int64
#  11  T                     383 non-null    int64
#  12  N                     383 non-null    int64
#  13  M                     383 non-null    int64
#  14  Stage                 383 non-null    int64
#  15  Response              383 non-null    int64
#  16  Recurred              383 non-null    int64
# dtypes: int64(17)
# memory usage: 51.0 KB

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 3ms/step - loss: 1.2620 - accuracy: 0.6111
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0618 - accuracy: 0.5850
# Epoch 3/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9344 - accuracy: 0.5980
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8950 - accuracy: 0.5523
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7490 - accuracy: 0.6373
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7538 - accuracy: 0.6373
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6995 - accuracy: 0.6405
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.6601
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6097 - accuracy: 0.7026
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6206 - accuracy: 0.6961
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6160 - accuracy: 0.6961
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6136 - accuracy: 0.7157
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6182 - accuracy: 0.7255
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5963 - accuracy: 0.6961
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5801 - accuracy: 0.7026
# Epoch 16/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5369 - accuracy: 0.7353
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5596 - accuracy: 0.7484
# Epoch 18/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5317 - accuracy: 0.7353
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.7745
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7614
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.7712
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.8170
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4932 - accuracy: 0.7647
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4949 - accuracy: 0.7745
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4582 - accuracy: 0.8039
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8301
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4653 - accuracy: 0.8072
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8431
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4245 - accuracy: 0.8235
# Epoch 30/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3747 - accuracy: 0.8235
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8203
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3901 - accuracy: 0.8627
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3984 - accuracy: 0.8497
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8235
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8170
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3381 - accuracy: 0.8399
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3512 - accuracy: 0.8464
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3670 - accuracy: 0.8627
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3246 - accuracy: 0.8824
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3608 - accuracy: 0.8497
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3396 - accuracy: 0.8824
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3596 - accuracy: 0.8595
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3036 - accuracy: 0.8889
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3122 - accuracy: 0.8758
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2912 - accuracy: 0.8954
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3079 - accuracy: 0.8725
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3193 - accuracy: 0.8791
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2961 - accuracy: 0.8922
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2654 - accuracy: 0.9052
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3110 - accuracy: 0.8954
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2959 - accuracy: 0.9085
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2830 - accuracy: 0.8954
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2897 - accuracy: 0.9085
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2963 - accuracy: 0.8856
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2856 - accuracy: 0.8758
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2914 - accuracy: 0.9020
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2727 - accuracy: 0.9085
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2705 - accuracy: 0.9020
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2504 - accuracy: 0.8856
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3157 - accuracy: 0.8824
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2645 - accuracy: 0.9020
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2697 - accuracy: 0.9020
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2509 - accuracy: 0.8987
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2772 - accuracy: 0.8987
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2772 - accuracy: 0.8954
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2504 - accuracy: 0.9216
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2610 - accuracy: 0.9052
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2426 - accuracy: 0.9085
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2903 - accuracy: 0.8987
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2408 - accuracy: 0.9216
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2686 - accuracy: 0.9118
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2552 - accuracy: 0.9052
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2603 - accuracy: 0.9150
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2443 - accuracy: 0.9118
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.9052
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.9020
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2327 - accuracy: 0.9216
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2355 - accuracy: 0.9020
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2604 - accuracy: 0.9020
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2337 - accuracy: 0.9216
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.9085
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2351 - accuracy: 0.9150
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2140 - accuracy: 0.9118
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2205 - accuracy: 0.9118
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2376 - accuracy: 0.9118
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2451 - accuracy: 0.9052
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2046 - accuracy: 0.9183
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2326 - accuracy: 0.9150
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9248
# Epoch 90/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2256 - accuracy: 0.9085
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2096 - accuracy: 0.9183
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2095 - accuracy: 0.9216
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1975 - accuracy: 0.9281
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2220 - accuracy: 0.9118
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2056 - accuracy: 0.9150
# Epoch 96/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2175 - accuracy: 0.9183
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2186 - accuracy: 0.9248
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9281
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2184 - accuracy: 0.9150
# Epoch 100/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2122 - accuracy: 0.9150

# %%
y_pred = model.predict(x_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
y_pred
# Out:
# array([[0.00292195],
#        [0.2762251 ],
#        [0.75266695],
#        [0.01659643],
#        [0.17354266],
#        [0.11366185],
#        [0.39823934],
#        [0.05822495],
#        [0.05975523],
#        [0.05243711],
#        [0.00965254],
#        [0.59471077],
#        [0.03186803],
#        [0.27206862],
#        [0.07967477],
#        [0.00537059],
#        [0.00526002],
#        [0.86440325],
#        [0.01769821],
#        [0.07288619],
#        [0.00959236],
#        [0.0378035 ],
#        [0.00588391],
#        [0.9853135 ],
#        [0.00379881],
#        [0.00444297],
#        [0.99936134],
#        [0.05221975],
#        [0.5024263 ],
#        [0.00944412],
#        [0.00555833],
#        [0.11522605],
#        [0.0040295 ],
#        [0.9468774 ],
#        [0.99709225],
#        [0.2656509 ],
#        [0.47698012],
#        [0.30546287],
#        [0.97628975],
#        [0.11816513],
#        [0.01036927],
#        [0.9997207 ],
#        [0.32856923],
#        [0.00705554],
#        [0.11510372],
#        [0.35767424],
#        [0.5232502 ],
#        [0.02464733],
#        [0.00492402],
#        [0.01192813],
#        [0.2906417 ],
#        [0.49692902],
#        [0.01094162],
#        [0.01556002],
#        [0.5278867 ],
#        [0.01821952],
#        [0.99997425],
#        [0.00514965],
#        [0.9949825 ],
#        [0.00567779],
#        [0.9997639 ],
#        [0.00520976],
#        [0.99977887],
#        [0.9185657 ],
#        [0.38212952],
#        [0.03389366],
#        [0.00638344],
#        [0.00574979],
#        [0.06294047],
#        [0.01061825],
#        [0.01329354],
#        [0.4503917 ],
#        [0.99204   ],
#        [0.934033  ],
#        [0.0061975 ],
#        [0.97558266],
#        [0.9827618 ]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# [[49  5]
#  [ 7 16]]
# 0.8441558441558441

# %%
arr=[ 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
       'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
       'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred']
for i in arr:
  print(f'{i}: ',df[i].unique())
# Out:
# Gender:  [0 1]
# Smoking:  [0 1]
# Hx Smoking:  [0 1]
# Hx Radiothreapy:  [0 1]
# Thyroid Function:  [2 0 1 3 4]
# Physical Examination:  [3 1 4 2 0]
# Adenopathy:  [3 5 1 2 0 4]
# Pathology:  [2 3 0 1]
# Focality:  [1 0]
# Risk:  [2 1 0]
# T:  [0 1 2 3 4 5 6]
# N:  [0 2 1]
# M:  [0 1]
# Stage:  [0 1 4 2 3]
# Response:  [2 1 3 0]
# Recurred:  [0 1]
